# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %% [markdown]
# matplotlib inline means this plot is in the line, so we can see it visually here

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[11,22,44,33]
plt.plot(x,y);

# %% [markdown]
#   This way of plotting is reffered to as stateless way of plotting

# %%
#1st method
fig= plt.figure() #creates a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
fig=plt.figure() #creates a figure
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y) #add some data
plt.show()

# %%
# 3rd method - recommended
fig, ax= plt.subplots()
ax.plot(x,y); #add some data

# %%
# 3rd method - recommended
fig, ax= plt.subplots()
ax.plot(x,[1,100,52,99]); #add some data

# %% [markdown]
# ## Matplotlib example workflow

# %%
#0. import matplotlib and get it ready for ploting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

#1. Prepare data
x=[1,2,3,4]
y=[11,44,22,55]

#2. Setup plot
fig, ax=plt.subplots(figsize=(10,10))

#3. Plot data
ax.plot(x,y)

#4. Customize Plot
ax.set(title="Sample Plot",
      xlabel='x-axis',
      ylabel='y-axis')
#5. Save & show (you save the whole figure)
fig.savefig("../sample-plot.png")

# %% [markdown]
# ## Making figure from numpy arrays
# We want
# * Line plots
# * Scatter plots
# * Bar plots
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Create some data
x=np.linspace(0,10,100)

# %%
#Plot the data
fig, ax=plt.subplots()
ax.plot(x,x**2);

# %%
# Use same data to scatter
fig, ax=plt.subplots()
ax.scatter(x,np.exp(x));

# %%
fig, ax=plt.subplots()
ax.scatter(x,np.sin(x));

# %%
# Make a plot from dictionary
nutbutter={"Almond":10,
          "Peanut":8,
          "Cashew":12}
fig, ax=plt.subplots()
ax.bar(nutbutter.keys(),nutbutter.values())
ax.set(title="Butter prices",
      ylabel="Proces '$'");

# %%
fig,ax=plt.subplots()
ax.barh(list(nutbutter.keys()),list(nutbutter.values()));

# %%
#Make some data
x=np.random.randn(1000)
fig,ax=plt.subplots()
ax.hist(x);

# %%
#Subplot 1
fig, ((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))

#Plot to each different axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nutbutter.keys(),nutbutter.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplot option 2
fig, ax=plt.subplots(nrows=2,ncols=2,figsize=(10,5))

# Plot to each different index
ax[0, 0].plot(x,x/2);
ax[0, 1].scatter(np.random.random(10),np.random.random(10));
ax[1, 0].bar(nutbutter.keys(),nutbutter.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting fro Pandas Dataframes

# %%
import pandas as pd
import matplotlib.pypl

# %%
# Make a dataframe
carsales= pd.read_csv("carsales.csv");
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), 
               index=pd.date_range("27/2/2022", periods=1000))

#ts
ts = ts.cumsum()

ts.plot()
# Out:
# <AxesSubplot:>

# %%
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
carsales.Price=carsales.Price.str.replace('[\$\,\.]','')
carsales
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_12364/2713223358.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   carsales.Price=carsales.Price.str.replace('[\$\,\.]','')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
carsales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
carsales=carsales.astype({"Price":int}) 
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
carsales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int32
# dtype: object

# %%
carsales.Price =  carsales.Price /100
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
carsales["SaleData"]= pd.date_range("27/2/2022", periods=len(carsales))
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price   SaleData
# 0  Toyota  White         150043      4   4000.0 2022-02-27
# 1   Honda    Red          87899      4   5000.0 2022-02-28
# 2  Toyota   Blue          32549      3   7000.0 2022-03-01
# 3     BMW  Black          11179      5  22000.0 2022-03-02
# 4  Nissan  White         213095      4   3500.0 2022-03-03
# 5  Toyota  Green          99213      4   4500.0 2022-03-04
# 6   Honda   Blue          45698      4   7500.0 2022-03-05
# 7   Honda   Blue          54738      4   7000.0 2022-03-06
# 8  Toyota  White          60000      4   6250.0 2022-03-07
# 9  Nissan  White          31600      4   9700.0 2022-03-08

# %%
carsales["Total sale"]=carsales.Price.cumsum()
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price   SaleData  Total sale
# 0  Toyota  White         150043      4   4000.0 2022-02-27      4000.0
# 1   Honda    Red          87899      4   5000.0 2022-02-28      9000.0
# 2  Toyota   Blue          32549      3   7000.0 2022-03-01     16000.0
# 3     BMW  Black          11179      5  22000.0 2022-03-02     38000.0
# 4  Nissan  White         213095      4   3500.0 2022-03-03     41500.0
# 5  Toyota  Green          99213      4   4500.0 2022-03-04     46000.0
# 6   Honda   Blue          45698      4   7500.0 2022-03-05     53500.0
# 7   Honda   Blue          54738      4   7000.0 2022-03-06     60500.0
# 8  Toyota  White          60000      4   6250.0 2022-03-07     66750.0
# 9  Nissan  White          31600      4   9700.0 2022-03-08     76450.0

# %%
# Lets plot total sales
carsales.plot(x="SaleData" ,y ="Total sale");

# %%
carsales.plot(x="Odometer (KM)", y="Price" , kind="scatter");

# %%
# How about a bar graph
x= np.random.rand(10,4);
x

# Turn it into a dataframe
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.938611  0.241388  0.298261  0.784033
# 1  0.858754  0.983691  0.622929  0.185881
# 2  0.900785  0.675641  0.367054  0.891212
# 3  0.966862  0.320825  0.877768  0.753196
# 4  0.523334  0.072856  0.192233  0.649762
# 5  0.496707  0.956778  0.144604  0.805401
# 6  0.586930  0.381225  0.381187  0.893961
# 7  0.647630  0.951167  0.448258  0.606303
# 8  0.477917  0.053588  0.982289  0.506635
# 9  0.927170  0.105377  0.418241  0.344372

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar');

# %%
carsales.plot(x='Make',y='Odometer (KM)',kind='bar');

# %%
# histograms
carsales["Odometer (KM)"].plot.hist();

# %%
heartdisease=pd.read_csv("heart-disease.csv")
heartdisease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Create a histogram just to see distribution of the age colm
heartdisease.age.plot.hist(bins=10);

# %%
heartdisease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heartdisease.plot.hist(figsize=(10,30), subplots=True);

# %% [markdown]
# ### Which one should you use? (pyplot vs matplotlib OO method)
# * When plotting something quickly, okay to use the pyplot method
# * When plotting somethink more advanced, use the OO method

# %%
heartdisease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over50=heartdisease[heartdisease.age > 50]
over50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#Pyplot method
over50.plot(kind='scatter',
           x='age',
           y='chol',
           c='target');

# %%
# OO method mixed with pyplot method
fig, ax=plt.subplots(figsize=(10,6))
over50.plot(kind='scatter',
           x='age',
           y='chol',
           ax=ax);

# %%
# Using OO mathod from scratch
fig, ax= plt.subplots(figsize=(10,6))
#Plot the data
scatter=ax.scatter(x=over50["age"],
                  y=over50["chol"],
                  c=over50["target"]);
#Customize the plot
ax.set(title="Heart Disease and Cholestrol Level",
      xlabel="Age",
      ylabel="Cholestrol");
# Add a legend
ax.legend(*scatter.legend_elements(),title="Target");

# Add a horizontal line
ax.axhline(over50["chol"].mean(),
          linestyle="--");

# %%
# Subplot of chol, age, thalach
fig, (ax0,ax1) = plt.subplots(nrows=2,
                              ncols=1,
                             figsize=(10,10));
# ADD data to ax0
scatter=ax0.scatter(x=over50.age,
                   y=over50.chol,
                   c=over50.target);
# Customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels",
       xlabel="Age",
       ylabel="Cholestrol");
# add a legend
ax0.legend(*scatter.legend_elements(),title="target")
# Add a meanline
ax0.axhline(y=over50.chol.mean(),linestyle="--");

# ADD data to ax1
scatter=ax1.scatter(x=over50.age,
                   y=over50.thalach,
                   c=over50.target);
# Customize ax1
ax1.set(title="Heart Disease and thalach Levels",
       xlabel="Age",
       ylabel="Max heart rate");
# add a legend
ax1.legend(*scatter.legend_elements(),title="target")
# Add a meanline
ax1.axhline(y=over50.thalach.mean(),linestyle="--");

# Add a fig to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %% [markdown]
# # Customizing Matplotlib plot and getting stylish

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-whitegrid")

# %%
carsales.Price.plot();

# %%
plt.style.use("seaborn")

# %%
carsales.Price.plot();

# %%
carsales.plot(x="Odometer (KM)", y="Price",kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
plt.style.use("ggplot")

# %%
carsales.Price.plot();

# %%
# Create some data
x = np.random.rand(10,4)
x
# Out:
# array([[0.32982638, 0.14614468, 0.12721004, 0.25706107],
#        [0.07862393, 0.43292643, 0.59164354, 0.7575467 ],
#        [0.49212959, 0.15829216, 0.46342828, 0.19509161],
#        [0.16654929, 0.27958069, 0.70399665, 0.71764281],
#        [0.32696591, 0.60954519, 0.72893096, 0.81518617],
#        [0.35135965, 0.20127646, 0.43306889, 0.08271401],
#        [0.57126391, 0.70150709, 0.76371211, 0.86724166],
#        [0.68404612, 0.37677474, 0.00407798, 0.86685556],
#        [0.07382763, 0.36769321, 0.04222839, 0.91450059],
#        [0.31867166, 0.57729308, 0.16216812, 0.88857256]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.329826  0.146145  0.127210  0.257061
# 1  0.078624  0.432926  0.591644  0.757547
# 2  0.492130  0.158292  0.463428  0.195092
# 3  0.166549  0.279581  0.703997  0.717643
# 4  0.326966  0.609545  0.728931  0.815186
# 5  0.351360  0.201276  0.433069  0.082714
# 6  0.571264  0.701507  0.763712  0.867242
# 7  0.684046  0.376775  0.004078  0.866856
# 8  0.073828  0.367693  0.042228  0.914501
# 9  0.318672  0.577293  0.162168  0.888573

# %%
ax = df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
# Customize out plot with the set() method
ax =  df.plot(kind='bar')
# Add some labels and a title
ax.set(title="Random Number Bar Graph from DataFrame",
      xlabel="Row number",
      ylabel="Random number")
ax.legend().set_visible(True);

# %%
plt.style.use("seaborn-whitegrid")
# Using OO mathod from scratch
fig, ax= plt.subplots(figsize=(10,6))
#Plot the data
scatter=ax.scatter(x=over50["age"],
                  y=over50["chol"],
                  c=over50["target"],
                  cmap="winter"); # this changes the colour scheme
#Customize the plot
ax.set(title="Heart Disease and Cholestrol Level",
      xlabel="Age",
      ylabel="Cholestrol");
# Add a legend
ax.legend(*scatter.legend_elements(),title="Target");

# Add a horizontal line
ax.axhline(over50["chol"].mean(),
          linestyle="--");

# %%
# Customizing x and y axes limitation

# Subplot of chol, age, thalach
fig, (ax0,ax1) = plt.subplots(nrows=2,
                              ncols=1,
                             figsize=(10,10));
# ADD data to ax0
scatter=ax0.scatter(x=over50.age,
                   y=over50.chol,
                   c=over50.target,
                   cmap='winter');
# Customize ax0
ax0.set(title="Heart Disease and Cholestrol Levels",
       xlabel="Age",
       ylabel="Cholestrol");

# change the x axis limits
ax0.set_xlim([50,80])

# add a legend
ax0.legend(*scatter.legend_elements(),title="target")
# Add a meanline
ax0.axhline(y=over50.chol.mean(),linestyle="--");

# ADD data to ax1
scatter=ax1.scatter(x=over50.age,
                   y=over50.thalach,
                   c=over50.target,
                   cmap='winter');
# Customize ax1
ax1.set(title="Heart Disease and thalach Levels",
       xlabel="Age",
       ylabel="Max heart rate");
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
# add a legend
ax1.legend(*scatter.legend_elements(),title="target")
# Add a meanline
ax1.axhline(y=over50.thalach.mean(),linestyle="--");

# Add a fig to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %%
fig

# %%
# Saving 
fig.savefig("Heart Disease analysis plot saved with code.png");
